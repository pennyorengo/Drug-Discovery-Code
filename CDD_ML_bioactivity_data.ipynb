# %% [markdown]
# # **Computational Drug Discovery Download Bioactivity Data**
#
# Penny Orengo
#
# In this Jupyter notebook, I will be building a real-life **data science project** that I will include in my **data science portfolio**. Particularly, I will be building a machine learning model using the ChEMBL bioactivity data.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that I can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 55 kB 1.3 MB/s
# ...
#      |████████████████████████████████| 60 kB 4.5 MB/s
# ...
#   Attempting uninstall: itsdangerous
#     Found existing installation: itsdangerous 1.1.0
#     Uninstalling itsdangerous-1.1.0:
#       Successfully uninstalled itsdangerous-1.1.0
#   Attempting uninstall: attrs
#     Found existing installation: attrs 22.1.0
#     Uninstalling attrs-22.1.0:
#       Successfully uninstalled attrs-22.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 1.1.4 requires itsdangerous<2.0,>=0.24, but you have itsdangerous 2.1.2 which is incompatible.
# ...

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for breast cancer**

# %%
# Target search for breast cancer
target = new_client.target
target_query = target.search('breast cancer')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references      organism  \
# 0   [{'xref_id': 'P38398', 'xref_name': None, 'xre...  Homo sapiens
# 1                                                  []  Homo sapiens
# 2   [{'xref_id': 'Q7RTN6', 'xref_name': None, 'xre...  Homo sapiens
# 3                                                  []  Homo sapiens
# 4                                                  []  Mus musculus
# ..                                                ...           ...
# 77                                                 []  Homo sapiens
# 78                                                 []  Homo sapiens
# 79                                                 []  Homo sapiens
# 80                                                 []  Homo sapiens
# 81                                                 []  Homo sapiens
#
#                                        pref_name  score  species_group_flag  \
# ...

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Breast cancer type 1 susceptibility protein* (first entry)**

# %% [markdown]
# We will assign the fisrt entry (which corresponds to the target protein, *Breast cancer type 1 susceptibility protein*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL5990'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Breast cancer type 1 susceptibility protein* (CHEMBL5990) that are reported as IC$_{50}$ values in nM (nanomolar) unit.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   activity_comment  activity_id activity_properties assay_chembl_id  \
# 0             None      6222842                  []   CHEMBL1785941
# 1             None      6222843                  []   CHEMBL1785941
# 2             None      6222844                  []   CHEMBL1785941
#
#                                    assay_description assay_type  \
# 0  Inhibition of BRCA1 by fluorescence polarizati...          B
# 1  Inhibition of BRCA1 by fluorescence polarizati...          B
# 2  Inhibition of BRCA1 by fluorescence polarizati...          B
#
#   assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                    None                   None  BAO_0000190  BAO_0000357
# 1                    None                   None  BAO_0000190  BAO_0000357
# 2                    None                   None  BAO_0000190  BAO_0000357
#
#    ... target_organism                             target_pref_name  \
# ...

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# Finally saving the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('bioactivity_data.csv', index=False)

# %% [markdown]
# ## **Copying files to Google Drive**

# %% [markdown]
# Firstly, we need to mount the Google Drive into Colab so that we can have access to our Google adrive from within Colab.

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# Next, we create a **data** folder in our **Colab Notebooks** folder on Google Drive.

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! cp bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls -l "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# total 11
# -rw------- 1 root root 11000 Sep 20 09:56 bioactivity_data.csv

# %% [markdown]
# Let's see the CSV files that we have so far.

# %%
! ls
# Out:
# bioactivity_data.csv  gdrive  sample_data

# %% [markdown]
# Taking a glimpse of the **bioactivity_data.csv** file that we've just created.

# %%
! head bioactivity_data.csv
# Out:
# activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ...

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** column then drop it

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#    activity_comment  activity_id activity_properties assay_chembl_id  \
# 0              None      6222842                  []   CHEMBL1785941
# 1              None      6222843                  []   CHEMBL1785941
# 2              None      6222844                  []   CHEMBL1785941
# 3              None      6222845                  []   CHEMBL1785941
# 4              None      6222846                  []   CHEMBL1785941
# 5              None      6222847                  []   CHEMBL1785941
# 6              None      6222848                  []   CHEMBL1785941
# 7              None      6222849                  []   CHEMBL1785941
# 8              None      6222850                  []   CHEMBL1785941
# 9              None      6222851                  []   CHEMBL1785941
# 10             None      6222852                  []   CHEMBL1785941
# 11             None      6222853                  []   CHEMBL1785941
# 12             None      6222854                  []   CHEMBL1785941
# ...

# %% [markdown]
# Apparently, for this dataset there is no missing data. But we can use the above code cell for bioactivity data of other target protein.

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# ### **Iterate the *assay_chembl_id* to a list**

# %%
assay_cid = []
for i in df2.assay_chembl_id:
  assay_cid.append(i)

# %% [markdown]
# ### **Iterate *canonical_smiles* to a list**

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %% [markdown]
# ### **Iterate *standard_value* to a list**

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %% [markdown]
# ### **Combine the 4 lists into a dataframe**

# %%
data_tuples = list(zip(assay_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame( data_tuples,  columns=['assay_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df3
# Out:
#    assay_chembl_id                                   canonical_smiles  \
# 0    CHEMBL1785941  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 1    CHEMBL1785941  CC(=O)N[C@@H](CCC(=O)O)C(=O)N1CCC[C@H]1C(=O)N[...
# 2    CHEMBL1785941  CC(=O)N[C@@H](CC(C(=O)O)C(=O)O)C(=O)N1CCC[C@H]...
# 3    CHEMBL1785941  CC(=O)N[C@H](C(=O)N1CCC[C@H]1C(=O)N[C@H](C(=O)...
# 4    CHEMBL1785941  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N[C@@H](C)C(=O)...
# 5    CHEMBL1785941  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 6    CHEMBL1785941  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 7    CHEMBL1785941  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 8    CHEMBL1785941  CC[C@H](C)[C@H](NC(=O)[C@@H]1CCCN1C(=O)[C@H](C...
# 9    CHEMBL1785941  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 10   CHEMBL1785941  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 11   CHEMBL1785941  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# ...

# %% [markdown]
# ### **Alternative method**

# %%
selection = ['assay_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2[selection]
df3
# Out:
#    assay_chembl_id                                   canonical_smiles  \
# 0    CHEMBL1785941  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 1    CHEMBL1785941  CC(=O)N[C@@H](CCC(=O)O)C(=O)N1CCC[C@H]1C(=O)N[...
# 2    CHEMBL1785941  CC(=O)N[C@@H](CC(C(=O)O)C(=O)O)C(=O)N1CCC[C@H]...
# 3    CHEMBL1785941  CC(=O)N[C@H](C(=O)N1CCC[C@H]1C(=O)N[C@H](C(=O)...
# 4    CHEMBL1785941  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N[C@@H](C)C(=O)...
# 5    CHEMBL1785941  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 6    CHEMBL1785941  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 7    CHEMBL1785941  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 8    CHEMBL1785941  CC[C@H](C)[C@H](NC(=O)[C@@H]1CCCN1C(=O)[C@H](C...
# 9    CHEMBL1785941  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 10   CHEMBL1785941  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 11   CHEMBL1785941  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# ...

# %%
pd.concat([df3,pd.Series(bioactivity_class)], axis=1)
# Out:
#    assay_chembl_id                                   canonical_smiles  \
# 0    CHEMBL1785941  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 1    CHEMBL1785941  CC(=O)N[C@@H](CCC(=O)O)C(=O)N1CCC[C@H]1C(=O)N[...
# 2    CHEMBL1785941  CC(=O)N[C@@H](CC(C(=O)O)C(=O)O)C(=O)N1CCC[C@H]...
# 3    CHEMBL1785941  CC(=O)N[C@H](C(=O)N1CCC[C@H]1C(=O)N[C@H](C(=O)...
# 4    CHEMBL1785941  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N[C@@H](C)C(=O)...
# 5    CHEMBL1785941  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 6    CHEMBL1785941  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 7    CHEMBL1785941  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 8    CHEMBL1785941  CC[C@H](C)[C@H](NC(=O)[C@@H]1CCCN1C(=O)[C@H](C...
# 9    CHEMBL1785941  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 10   CHEMBL1785941  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 11   CHEMBL1785941  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('bioactivity_preprocessed_data.csv', index=False)

# %%
! ls -l
# Out:
# total 24
# -rw-r--r-- 1 root root 11000 Sep 20 09:54 bioactivity_data.csv
# -rw-r--r-- 1 root root  2241 Sep 20 10:14 bioactivity_preprocessed_data.csv
# drwx------ 5 root root  4096 Sep 20 09:55 gdrive
# drwxr-xr-x 1 root root  4096 Sep 14 13:44 sample_data

# %% [markdown]
# Let's copy to the Google Drive

# %%
! cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# bioactivity_data.csv  bioactivity_preprocessed_data.csv

# %% [markdown]
# ---
